# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy  
from config import weather_api_key
import time
from datetime import datetime
import requests

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="
key = weather_api_key
request_url = f"{url}{key}"

# %%
lat = round(boston_data["coord"]["lat"],2)

# %%
#gathers coordinates and creates list named 'cities'
coordinates = list(lat_lngs)
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)

# %%
len(cities)
# Out:
# 740

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = request_url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ") 
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | nouakchott
# Processing Record 2 of Set 1 | araouane
# Processing Record 3 of Set 1 | avarua
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | pangnirtung
# Processing Record 6 of Set 1 | pisco
# Processing Record 7 of Set 1 | kaitangata
# Processing Record 8 of Set 1 | yulara
# Processing Record 9 of Set 1 | bilibino
# Processing Record 10 of Set 1 | fortuna
# Processing Record 11 of Set 1 | eureka
# Processing Record 12 of Set 1 | liberty
# Processing Record 13 of Set 1 | bredasdorp
# Processing Record 14 of Set 1 | boguchany
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | narsaq
# Processing Record 17 of Set 1 | cape town
# Processing Record 18 of Set 1 | conde
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | mokhsogollokh
# Processing Record 24 of Set 1 | inta
# Processing Record 25 of Set 1 | mongo
# Processing Record 26 of Set 1 | saint george
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | tuktoyaktuk
# Processing Record 29 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 1 | isangel
# Processing Record 31 of Set 1 | qaanaaq
# Processing Record 32 of Set 1 | hilo
# Processing Record 33 of Set 1 | kamenka
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | port macquarie
# Processing Record 36 of Set 1 | namibe
# Processing Record 37 of Set 1 | roald
# Processing Record 38 of Set 1 | okhotsk
# Processing Record 39 of Set 1 | lardos
# Processing Record 40 of Set 1 | leh
# Processing Record 41 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 42 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 1 | takaka
# Processing Record 44 of Set 1 | atikokan
# Processing Record 45 of Set 1 | vardo
# Processing Record 46 of Set 1 | puerto ayora
# Processing Record 47 of Set 1 | zeya
# Processing Record 48 of Set 1 | mar del plata
# Processing Record 49 of Set 1 | iqaluit
# Processing Record 50 of Set 1 | grindavik
# Processing Record 1 of Set 2 | ribeira grande
# Processing Record 2 of Set 2 | kapaa
# Processing Record 3 of Set 2 | mount gambier
# Processing Record 4 of Set 2 | barrow
# Processing Record 5 of Set 2 | itigi
# Processing Record 6 of Set 2 | maniitsoq
# Processing Record 7 of Set 2 | saint-philippe
# Processing Record 8 of Set 2 | onoda
# Processing Record 9 of Set 2 | saskylakh
# Processing Record 10 of Set 2 | teknaf
# Processing Record 11 of Set 2 | mecca
# Processing Record 12 of Set 2 | bilma
# Processing Record 13 of Set 2 | vaini
# Processing Record 14 of Set 2 | torbay
# Processing Record 15 of Set 2 | kavieng
# Processing Record 16 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 2 | westerland
# Processing Record 18 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 2 | pizarro
# Processing Record 20 of Set 2 | reconquista
# Processing Record 21 of Set 2 | college
# Processing Record 22 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 23 of Set 2 | albany
# Processing Record 24 of Set 2 | cabo san lucas
# Processing Record 25 of Set 2 | karpogory
# Processing Record 26 of Set 2 | new norfolk
# Processing Record 27 of Set 2 | gumdag
# Processing Record 28 of Set 2 | salalah
# Processing Record 29 of Set 2 | east london
# Processing Record 30 of Set 2 | thompson
# Processing Record 31 of Set 2 | saint anthony
# Processing Record 32 of Set 2 | galle
# Processing Record 33 of Set 2 | rio gallegos
# Processing Record 34 of Set 2 | karratha
# Processing Record 35 of Set 2 | hithadhoo
# Processing Record 36 of Set 2 | port saint lucie
# Processing Record 37 of Set 2 | clyde river
# Processing Record 38 of Set 2 | port elizabeth
# Processing Record 39 of Set 2 | bonavista
# Processing Record 40 of Set 2 | carnarvon
# Processing Record 41 of Set 2 | tuatapere
# Processing Record 42 of Set 2 | bluff
# Processing Record 43 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 2 | codrington
# Processing Record 45 of Set 2 | burnie
# Processing Record 46 of Set 2 | pangai
# Processing Record 47 of Set 2 | manicore
# Processing Record 48 of Set 2 | khatanga
# Processing Record 49 of Set 2 | port-gentil
# Processing Record 50 of Set 2 | bitung
# Processing Record 1 of Set 3 | lagunas
# Processing Record 2 of Set 3 | jawhar
# Processing Record 3 of Set 3 | ulladulla
# Processing Record 4 of Set 3 | hobart
# Processing Record 5 of Set 3 | stantsiya gorchakovo
# City not found. Skipping...
# Processing Record 6 of Set 3 | tasiilaq
# Processing Record 7 of Set 3 | mikhaylovka
# Processing Record 8 of Set 3 | dragu
# Processing Record 9 of Set 3 | dingle
# Processing Record 10 of Set 3 | lasa
# Processing Record 11 of Set 3 | biak
# Processing Record 12 of Set 3 | braslav
# City not found. Skipping...
# Processing Record 13 of Set 3 | port lincoln
# Processing Record 14 of Set 3 | sitka
# Processing Record 15 of Set 3 | agadir
# Processing Record 16 of Set 3 | klaksvik
# Processing Record 17 of Set 3 | tocopilla
# Processing Record 18 of Set 3 | bengkulu
# Processing Record 19 of Set 3 | samarinda
# Processing Record 20 of Set 3 | hojai
# Processing Record 21 of Set 3 | bemidji
# Processing Record 22 of Set 3 | nadym
# Processing Record 23 of Set 3 | victoria
# Processing Record 24 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 3 | provideniya
# Processing Record 26 of Set 3 | longyearbyen
# Processing Record 27 of Set 3 | korla
# Processing Record 28 of Set 3 | gizo
# Processing Record 29 of Set 3 | hermanus
# Processing Record 30 of Set 3 | amarpur
# Processing Record 31 of Set 3 | nyimba
# Processing Record 32 of Set 3 | butaritari
# Processing Record 33 of Set 3 | tarata
# Processing Record 34 of Set 3 | hasaki
# Processing Record 35 of Set 3 | vostok
# Processing Record 36 of Set 3 | itoman
# Processing Record 37 of Set 3 | vestmannaeyjar
# Processing Record 38 of Set 3 | mehamn
# Processing Record 39 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 3 | naryan-mar
# Processing Record 41 of Set 3 | diamantino
# Processing Record 42 of Set 3 | broken hill
# Processing Record 43 of Set 3 | arraial do cabo
# Processing Record 44 of Set 3 | iquique
# Processing Record 45 of Set 3 | neyshabur
# Processing Record 46 of Set 3 | talnakh
# Processing Record 47 of Set 3 | yellowknife
# Processing Record 48 of Set 3 | charters towers
# Processing Record 49 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 3 | san patricio
# Processing Record 1 of Set 4 | port hedland
# Processing Record 2 of Set 4 | banjar
# Processing Record 3 of Set 4 | kulhudhuffushi
# Processing Record 4 of Set 4 | kimparana
# Processing Record 5 of Set 4 | viedma
# Processing Record 6 of Set 4 | hamilton
# Processing Record 7 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 4 | san quintin
# Processing Record 9 of Set 4 | port alfred
# Processing Record 10 of Set 4 | the pas
# Processing Record 11 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 4 | norsup
# Processing Record 13 of Set 4 | opuwo
# Processing Record 14 of Set 4 | zhigansk
# Processing Record 15 of Set 4 | coxim
# Processing Record 16 of Set 4 | tessalit
# Processing Record 17 of Set 4 | la libertad
# Processing Record 18 of Set 4 | matara
# Processing Record 19 of Set 4 | mpanda
# Processing Record 20 of Set 4 | norman wells
# Processing Record 21 of Set 4 | cherskiy
# Processing Record 22 of Set 4 | luderitz
# Processing Record 23 of Set 4 | lompoc
# Processing Record 24 of Set 4 | laguna
# Processing Record 25 of Set 4 | shitanjing
# Processing Record 26 of Set 4 | mahebourg
# Processing Record 27 of Set 4 | lahat
# Processing Record 28 of Set 4 | moroni
# Processing Record 29 of Set 4 | castro
# Processing Record 30 of Set 4 | cidreira
# Processing Record 31 of Set 4 | tiksi
# Processing Record 32 of Set 4 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 33 of Set 4 | xai-xai
# Processing Record 34 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 4 | lagoa
# Processing Record 36 of Set 4 | taihe
# Processing Record 37 of Set 4 | ostrovnoy
# Processing Record 38 of Set 4 | veraval
# Processing Record 39 of Set 4 | luhyny
# Processing Record 40 of Set 4 | mandasa
# Processing Record 41 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 4 | fort thomas
# Processing Record 43 of Set 4 | dikson
# Processing Record 44 of Set 4 | chalchihuites
# Processing Record 45 of Set 4 | tupik
# Processing Record 46 of Set 4 | kruisfontein
# Processing Record 47 of Set 4 | ewa beach
# Processing Record 48 of Set 4 | ust-tsilma
# Processing Record 49 of Set 4 | twante
# Processing Record 50 of Set 4 | kutum
# Processing Record 1 of Set 5 | gazni
# City not found. Skipping...
# Processing Record 2 of Set 5 | sorong
# Processing Record 3 of Set 5 | miri
# Processing Record 4 of Set 5 | pingshan
# Processing Record 5 of Set 5 | georgetown
# Processing Record 6 of Set 5 | upernavik
# Processing Record 7 of Set 5 | progreso
# Processing Record 8 of Set 5 | marienburg
# Processing Record 9 of Set 5 | bezhta
# Processing Record 10 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 11 of Set 5 | chokurdakh
# Processing Record 12 of Set 5 | port moresby
# Processing Record 13 of Set 5 | kloulklubed
# Processing Record 14 of Set 5 | dutlwe
# Processing Record 15 of Set 5 | alice springs
# Processing Record 16 of Set 5 | antalaha
# Processing Record 17 of Set 5 | poum
# Processing Record 18 of Set 5 | katrineholm
# Processing Record 19 of Set 5 | bethel
# Processing Record 20 of Set 5 | elbistan
# Processing Record 21 of Set 5 | yinchuan
# Processing Record 22 of Set 5 | bagdarin
# Processing Record 23 of Set 5 | lamu
# Processing Record 24 of Set 5 | camacha
# Processing Record 25 of Set 5 | buta
# Processing Record 26 of Set 5 | lukovetskiy
# Processing Record 27 of Set 5 | tezu
# Processing Record 28 of Set 5 | taoudenni
# Processing Record 29 of Set 5 | brokopondo
# Processing Record 30 of Set 5 | hovd
# Processing Record 31 of Set 5 | airai
# Processing Record 32 of Set 5 | valdivia
# Processing Record 33 of Set 5 | pangoa
# Processing Record 34 of Set 5 | siderno
# Processing Record 35 of Set 5 | pinawa
# Processing Record 36 of Set 5 | skjervoy
# Processing Record 37 of Set 5 | ahipara
# Processing Record 38 of Set 5 | port hardy
# Processing Record 39 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 5 | misasi
# Processing Record 41 of Set 5 | gorshechnoye
# Processing Record 42 of Set 5 | magnolia
# Processing Record 43 of Set 5 | rosetta
# Processing Record 44 of Set 5 | katsiveli
# City not found. Skipping...
# Processing Record 45 of Set 5 | cervo
# Processing Record 46 of Set 5 | sydney mines
# Processing Record 47 of Set 5 | san cristobal
# Processing Record 48 of Set 5 | yaan
# Processing Record 49 of Set 5 | ponta do sol
# Processing Record 50 of Set 5 | kununurra
# Processing Record 1 of Set 6 | mangaluru
# Processing Record 2 of Set 6 | aykhal
# Processing Record 3 of Set 6 | flin flon
# Processing Record 4 of Set 6 | kedrovyy
# Processing Record 5 of Set 6 | coahuayana
# Processing Record 6 of Set 6 | faanui
# Processing Record 7 of Set 6 | daru
# Processing Record 8 of Set 6 | kamaishi
# Processing Record 9 of Set 6 | bambanglipuro
# Processing Record 10 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 11 of Set 6 | pringsewu
# Processing Record 12 of Set 6 | girne
# Processing Record 13 of Set 6 | brainerd
# Processing Record 14 of Set 6 | shu
# Processing Record 15 of Set 6 | lavrentiya
# Processing Record 16 of Set 6 | ambon
# Processing Record 17 of Set 6 | khash
# Processing Record 18 of Set 6 | krasnoselkup
# Processing Record 19 of Set 6 | saldanha
# Processing Record 20 of Set 6 | setermoen
# Processing Record 21 of Set 6 | touros
# Processing Record 22 of Set 6 | tilbury
# Processing Record 23 of Set 6 | huittinen
# Processing Record 24 of Set 6 | gewane
# Processing Record 25 of Set 6 | nikolskoye
# Processing Record 26 of Set 6 | payson
# Processing Record 27 of Set 6 | thinadhoo
# Processing Record 28 of Set 6 | rawson
# Processing Record 29 of Set 6 | tvrdosin
# Processing Record 30 of Set 6 | aklavik
# Processing Record 31 of Set 6 | labuhan
# Processing Record 32 of Set 6 | toora-khem
# Processing Record 33 of Set 6 | kodiak
# Processing Record 34 of Set 6 | necochea
# Processing Record 35 of Set 6 | parma
# Processing Record 36 of Set 6 | chicontepec
# Processing Record 37 of Set 6 | klichka
# Processing Record 38 of Set 6 | oranjemund
# Processing Record 39 of Set 6 | ilulissat
# Processing Record 40 of Set 6 | brunico
# Processing Record 41 of Set 6 | maceio
# Processing Record 42 of Set 6 | kabanjahe
# Processing Record 43 of Set 6 | pincher creek
# Processing Record 44 of Set 6 | catumbela
# Processing Record 45 of Set 6 | ellensburg
# Processing Record 46 of Set 6 | maroua
# Processing Record 47 of Set 6 | te anau
# Processing Record 48 of Set 6 | marzuq
# Processing Record 49 of Set 6 | nishihara
# Processing Record 50 of Set 6 | esperance
# Processing Record 1 of Set 7 | kailua
# Processing Record 2 of Set 7 | kabinda
# Processing Record 3 of Set 7 | salinopolis
# Processing Record 4 of Set 7 | miass
# Processing Record 5 of Set 7 | ketchikan
# Processing Record 6 of Set 7 | middelburg
# Processing Record 7 of Set 7 | yar-sale
# Processing Record 8 of Set 7 | belmonte
# Processing Record 9 of Set 7 | olafsvik
# Processing Record 10 of Set 7 | moctezuma
# Processing Record 11 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 7 | mnogovershinnyy
# Processing Record 13 of Set 7 | souillac
# Processing Record 14 of Set 7 | omboue
# Processing Record 15 of Set 7 | ukiah
# Processing Record 16 of Set 7 | cedral
# Processing Record 17 of Set 7 | quatre cocos
# Processing Record 18 of Set 7 | chepareria
# Processing Record 19 of Set 7 | san ramon
# Processing Record 20 of Set 7 | macaboboni
# City not found. Skipping...
# Processing Record 21 of Set 7 | vao
# Processing Record 22 of Set 7 | mataram
# Processing Record 23 of Set 7 | abu jubayhah
# City not found. Skipping...
# Processing Record 24 of Set 7 | sergeyevka
# Processing Record 25 of Set 7 | kangaatsiaq
# Processing Record 26 of Set 7 | krasnoye
# Processing Record 27 of Set 7 | lieksa
# Processing Record 28 of Set 7 | boa vista
# Processing Record 29 of Set 7 | sao filipe
# Processing Record 30 of Set 7 | paita
# Processing Record 31 of Set 7 | nemuro
# Processing Record 32 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 33 of Set 7 | stawell
# Processing Record 34 of Set 7 | kurilsk
# Processing Record 35 of Set 7 | shimoda
# Processing Record 36 of Set 7 | tucuma
# Processing Record 37 of Set 7 | asau
# Processing Record 38 of Set 7 | glazov
# Processing Record 39 of Set 7 | qaqortoq
# Processing Record 40 of Set 7 | leningradskiy
# Processing Record 41 of Set 7 | ayorou
# Processing Record 42 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 7 | karabulak
# Processing Record 44 of Set 7 | acapulco
# Processing Record 45 of Set 7 | gordeyevka
# Processing Record 46 of Set 7 | tautira
# Processing Record 47 of Set 7 | erenhot
# Processing Record 48 of Set 7 | vanimo
# Processing Record 49 of Set 7 | alofi
# Processing Record 50 of Set 7 | magadan
# Processing Record 1 of Set 8 | sambava
# Processing Record 2 of Set 8 | altay
# Processing Record 3 of Set 8 | guerrero negro
# Processing Record 4 of Set 8 | lebu
# Processing Record 5 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 8 | aksu
# Processing Record 7 of Set 8 | avera
# Processing Record 8 of Set 8 | bend
# Processing Record 9 of Set 8 | makokou
# Processing Record 10 of Set 8 | abiy adi
# City not found. Skipping...
# Processing Record 11 of Set 8 | mpongwe
# Processing Record 12 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 8 | kalabo
# Processing Record 14 of Set 8 | sayyan
# Processing Record 15 of Set 8 | lakatoro
# Processing Record 16 of Set 8 | rathenow
# Processing Record 17 of Set 8 | inhambane
# Processing Record 18 of Set 8 | teluk nibung
# Processing Record 19 of Set 8 | edd
# Processing Record 20 of Set 8 | puerto leguizamo
# Processing Record 21 of Set 8 | yerbogachen
# Processing Record 22 of Set 8 | mount isa
# Processing Record 23 of Set 8 | meulaboh
# Processing Record 24 of Set 8 | san jose
# Processing Record 25 of Set 8 | preobrazheniye
# Processing Record 26 of Set 8 | dumai
# Processing Record 27 of Set 8 | price
# Processing Record 28 of Set 8 | puerto madryn
# Processing Record 29 of Set 8 | lagos
# Processing Record 30 of Set 8 | otjimbingwe
# Processing Record 31 of Set 8 | barcelos
# Processing Record 32 of Set 8 | poronaysk
# Processing Record 33 of Set 8 | haines junction
# Processing Record 34 of Set 8 | komsomolskiy
# Processing Record 35 of Set 8 | ugoofaaru
# Processing Record 36 of Set 8 | cabo rojo
# Processing Record 37 of Set 8 | kochi
# Processing Record 38 of Set 8 | severnoye
# Processing Record 39 of Set 8 | guymon
# Processing Record 40 of Set 8 | mackay
# Processing Record 41 of Set 8 | danjiangkou
# Processing Record 42 of Set 8 | celestun
# Processing Record 43 of Set 8 | marathon
# Processing Record 44 of Set 8 | angoche
# Processing Record 45 of Set 8 | mafinga
# Processing Record 46 of Set 8 | afrikanda
# Processing Record 47 of Set 8 | orange cove
# Processing Record 48 of Set 8 | balotra
# Processing Record 49 of Set 8 | praia
# Processing Record 50 of Set 8 | noumea
# Processing Record 1 of Set 9 | wamba
# Processing Record 2 of Set 9 | broome
# Processing Record 3 of Set 9 | portland
# Processing Record 4 of Set 9 | pochutla
# Processing Record 5 of Set 9 | vokhma
# Processing Record 6 of Set 9 | lorengau
# Processing Record 7 of Set 9 | nynashamn
# Processing Record 8 of Set 9 | monrovia
# Processing Record 9 of Set 9 | sola
# Processing Record 10 of Set 9 | nioro
# Processing Record 11 of Set 9 | la paz
# Processing Record 12 of Set 9 | champerico
# Processing Record 13 of Set 9 | vizinga
# Processing Record 14 of Set 9 | cayenne
# Processing Record 15 of Set 9 | yeroham
# Processing Record 16 of Set 9 | spas-klepiki
# Processing Record 17 of Set 9 | shingu
# Processing Record 18 of Set 9 | ayios matthaios
# City not found. Skipping...
# Processing Record 19 of Set 9 | takoradi
# Processing Record 20 of Set 9 | erzin
# Processing Record 21 of Set 9 | antofagasta
# Processing Record 22 of Set 9 | campobello di mazara
# Processing Record 23 of Set 9 | balabac
# Processing Record 24 of Set 9 | pont-a-mousson
# Processing Record 25 of Set 9 | harper
# Processing Record 26 of Set 9 | luna
# Processing Record 27 of Set 9 | paamiut
# Processing Record 28 of Set 9 | pozo colorado
# Processing Record 29 of Set 9 | padang
# Processing Record 30 of Set 9 | prainha
# Processing Record 31 of Set 9 | banda aceh
# Processing Record 32 of Set 9 | san-pedro
# Processing Record 33 of Set 9 | bonthe
# Processing Record 34 of Set 9 | zyryanskoye
# Processing Record 35 of Set 9 | banyo
# Processing Record 36 of Set 9 | nhulunbuy
# Processing Record 37 of Set 9 | victor harbor
# Processing Record 38 of Set 9 | pontes e lacerda
# Processing Record 39 of Set 9 | saint-pierre
# Processing Record 40 of Set 9 | tias
# Processing Record 41 of Set 9 | nanakuli
# Processing Record 42 of Set 9 | nchelenge
# Processing Record 43 of Set 9 | muborak
# Processing Record 44 of Set 9 | falam
# Processing Record 45 of Set 9 | urupes
# Processing Record 46 of Set 9 | sur
# Processing Record 47 of Set 9 | ozernovskiy
# Processing Record 48 of Set 9 | oregon
# Processing Record 49 of Set 9 | alugan
# Processing Record 50 of Set 9 | omsukchan
# Processing Record 1 of Set 10 | vrangel
# Processing Record 2 of Set 10 | balaguer
# Processing Record 3 of Set 10 | archidona
# Processing Record 4 of Set 10 | llallagua
# Processing Record 5 of Set 10 | syamzha
# Processing Record 6 of Set 10 | xining
# Processing Record 7 of Set 10 | amapa
# Processing Record 8 of Set 10 | beyneu
# Processing Record 9 of Set 10 | srednekolymsk
# Processing Record 10 of Set 10 | geraldton
# Processing Record 11 of Set 10 | marawi
# Processing Record 12 of Set 10 | katima mulilo
# Processing Record 13 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 14 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 15 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 10 | vorukh
# Processing Record 17 of Set 10 | bezenchuk
# Processing Record 18 of Set 10 | arlit
# Processing Record 19 of Set 10 | yantal
# Processing Record 20 of Set 10 | mafra
# Processing Record 21 of Set 10 | arona
# Processing Record 22 of Set 10 | hofn
# Processing Record 23 of Set 10 | xam nua
# Processing Record 24 of Set 10 | la asuncion
# Processing Record 25 of Set 10 | fort saint james
# Processing Record 26 of Set 10 | riwaka
# Processing Record 27 of Set 10 | dibulla
# Processing Record 28 of Set 10 | dicabisagan
# Processing Record 29 of Set 10 | nanortalik
# Processing Record 30 of Set 10 | oyama
# Processing Record 31 of Set 10 | rocha
# Processing Record 32 of Set 10 | yenagoa
# Processing Record 33 of Set 10 | goderich
# Processing Record 34 of Set 10 | san lorenzo
# Processing Record 35 of Set 10 | juybar
# Processing Record 36 of Set 10 | armacao dos buzios
# City not found. Skipping...
# Processing Record 37 of Set 10 | alice town
# Processing Record 38 of Set 10 | ust-kan
# Processing Record 39 of Set 10 | tual
# Processing Record 40 of Set 10 | bukama
# Processing Record 41 of Set 10 | tabou
# Processing Record 42 of Set 10 | raufoss
# Processing Record 43 of Set 10 | coquimbo
# Processing Record 44 of Set 10 | pemangkat
# Processing Record 45 of Set 10 | steamboat springs
# Processing Record 46 of Set 10 | pontianak
# Processing Record 47 of Set 10 | waddan
# Processing Record 48 of Set 10 | lloydminster
# Processing Record 49 of Set 10 | rabaul
# Processing Record 50 of Set 10 | kodinsk
# Processing Record 1 of Set 11 | vila franca do campo
# Processing Record 2 of Set 11 | bambous virieux
# Processing Record 3 of Set 11 | gualeguay
# Processing Record 4 of Set 11 | calabozo
# Processing Record 5 of Set 11 | homnabad
# Processing Record 6 of Set 11 | fayaoue
# Processing Record 7 of Set 11 | ikast
# Processing Record 8 of Set 11 | oeiras
# Processing Record 9 of Set 11 | shenzhen
# Processing Record 10 of Set 11 | santa cruz
# Processing Record 11 of Set 11 | candido mendes
# Processing Record 12 of Set 11 | vilani
# Processing Record 13 of Set 11 | drovyanaya
# Processing Record 14 of Set 11 | novovoronezh
# Processing Record 15 of Set 11 | kaka
# Processing Record 16 of Set 11 | melfi
# Processing Record 17 of Set 11 | cockburn town
# Processing Record 18 of Set 11 | najran
# Processing Record 19 of Set 11 | severo-kurilsk
# Processing Record 20 of Set 11 | itarema
# Processing Record 21 of Set 11 | talcahuano
# Processing Record 22 of Set 11 | hirara
# Processing Record 23 of Set 11 | grand gaube
# Processing Record 24 of Set 11 | lucapa
# Processing Record 25 of Set 11 | mildura
# Processing Record 26 of Set 11 | tilichiki
# Processing Record 27 of Set 11 | palu
# Processing Record 28 of Set 11 | tambopata
# Processing Record 29 of Set 11 | maragogi
# Processing Record 30 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 11 | bismarck
# Processing Record 32 of Set 11 | mount pleasant
# Processing Record 33 of Set 11 | saint-dizier
# Processing Record 34 of Set 11 | diapaga
# Processing Record 35 of Set 11 | sturlic
# Processing Record 36 of Set 11 | maxixe
# Processing Record 37 of Set 11 | monte azul
# Processing Record 38 of Set 11 | egvekinot
# Processing Record 39 of Set 11 | lata
# Processing Record 40 of Set 11 | abidjan
# Processing Record 41 of Set 11 | mastic beach
# Processing Record 42 of Set 11 | margate
# Processing Record 43 of Set 11 | ucluelet
# Processing Record 44 of Set 11 | sal rei
# Processing Record 45 of Set 11 | andenes
# Processing Record 46 of Set 11 | zelenoborskiy
# Processing Record 47 of Set 11 | gazanjyk
# Processing Record 48 of Set 11 | maltahohe
# Processing Record 49 of Set 11 | nikolayevka
# Processing Record 50 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 1 of Set 12 | drexel heights
# Processing Record 2 of Set 12 | iranshahr
# Processing Record 3 of Set 12 | ballachulish
# Processing Record 4 of Set 12 | garzon
# Processing Record 5 of Set 12 | inuvik
# Processing Record 6 of Set 12 | kungurtug
# Processing Record 7 of Set 12 | middle island
# Processing Record 8 of Set 12 | los llanos de aridane
# Processing Record 9 of Set 12 | gejiu
# Processing Record 10 of Set 12 | aleksandrov gay
# Processing Record 11 of Set 12 | kang
# Processing Record 12 of Set 12 | santa isabel do rio negro
# Processing Record 13 of Set 12 | taywarah
# Processing Record 14 of Set 12 | red wing
# Processing Record 15 of Set 12 | pindi gheb
# Processing Record 16 of Set 12 | morondava
# Processing Record 17 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 18 of Set 12 | saryozek
# Processing Record 19 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 20 of Set 12 | eskasem
# City not found. Skipping...
# Processing Record 21 of Set 12 | mamallapuram
# Processing Record 22 of Set 12 | terra santa
# Processing Record 23 of Set 12 | diffa
# Processing Record 24 of Set 12 | pevek
# Processing Record 25 of Set 12 | loreto
# Processing Record 26 of Set 12 | tianpeng
# Processing Record 27 of Set 12 | dubbo
# Processing Record 28 of Set 12 | salvador
# Processing Record 29 of Set 12 | northam
# Processing Record 30 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 31 of Set 12 | alyangula
# Processing Record 32 of Set 12 | athabasca
# Processing Record 33 of Set 12 | chudniv
# Processing Record 34 of Set 12 | jogindarnagar
# Processing Record 35 of Set 12 | punta alta
# Processing Record 36 of Set 12 | ismailia
# Processing Record 37 of Set 12 | vung tau
# Processing Record 38 of Set 12 | san juan
# Processing Record 39 of Set 12 | kaohsiung
# Processing Record 40 of Set 12 | atambua
# Processing Record 41 of Set 12 | troy
# Processing Record 42 of Set 12 | chongwe
# Processing Record 43 of Set 12 | menongue
# Processing Record 44 of Set 12 | altamira
# Processing Record 45 of Set 12 | moose factory
# Processing Record 46 of Set 12 | langsa
# Processing Record 47 of Set 12 | karamken
# City not found. Skipping...
# Processing Record 48 of Set 12 | ambilobe
# Processing Record 49 of Set 12 | marsh harbour
# Processing Record 50 of Set 12 | male
# Processing Record 1 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 2 of Set 13 | lisakovsk
# Processing Record 3 of Set 13 | westlock
# Processing Record 4 of Set 13 | leshukonskoye
# Processing Record 5 of Set 13 | palmer
# Processing Record 6 of Set 13 | gorontalo
# Processing Record 7 of Set 13 | dawson creek
# Processing Record 8 of Set 13 | acarau
# Processing Record 9 of Set 13 | datong
# Processing Record 10 of Set 13 | roma
# Processing Record 11 of Set 13 | stepnogorsk
# Processing Record 12 of Set 13 | ponta delgada
# Processing Record 13 of Set 13 | katsuura
# Processing Record 14 of Set 13 | roblin
# Processing Record 15 of Set 13 | vanavara
# Processing Record 16 of Set 13 | voh
# Processing Record 17 of Set 13 | drayton valley
# Processing Record 18 of Set 13 | comodoro rivadavia
# Processing Record 19 of Set 13 | paignton
# Processing Record 20 of Set 13 | sumenep
# Processing Record 21 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 22 of Set 13 | nouadhibou
# Processing Record 23 of Set 13 | sandnessjoen
# Processing Record 24 of Set 13 | remanso
# Processing Record 25 of Set 13 | beringovskiy
# Processing Record 26 of Set 13 | emirdag
# Processing Record 27 of Set 13 | darhan
# Processing Record 28 of Set 13 | koungou
# Processing Record 29 of Set 13 | tenochtitlan
# Processing Record 30 of Set 13 | verkhnyaya inta
# Processing Record 31 of Set 13 | rawlins
# Processing Record 32 of Set 13 | honiara
# Processing Record 33 of Set 13 | kostomuksha
# Processing Record 34 of Set 13 | tabuk
# Processing Record 35 of Set 13 | strezhevoy
# Processing Record 36 of Set 13 | dakar
# Processing Record 37 of Set 13 | udachnyy
# Processing Record 38 of Set 13 | faya
# Processing Record 39 of Set 13 | samarai
# Processing Record 40 of Set 13 | susehri
# Processing Record 41 of Set 13 | la ronge
# Processing Record 42 of Set 13 | shenjiamen
# Processing Record 43 of Set 13 | zharkent
# Processing Record 44 of Set 13 | poso
# Processing Record 45 of Set 13 | zhangjiakou
# Processing Record 46 of Set 13 | bandarbeyla
# Processing Record 47 of Set 13 | lalibela
# Processing Record 48 of Set 13 | chuy
# Processing Record 49 of Set 13 | safranbolu
# Processing Record 50 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 1 of Set 14 | manokwari
# Processing Record 2 of Set 14 | constitucion
# Processing Record 3 of Set 14 | vitim
# Processing Record 4 of Set 14 | nizwa
# Processing Record 5 of Set 14 | podosinovets
# Processing Record 6 of Set 14 | puksoozero
# Processing Record 7 of Set 14 | ko samui
# Processing Record 8 of Set 14 | carroll
# Processing Record 9 of Set 14 | upata
# Processing Record 10 of Set 14 | pokhara
# Processing Record 11 of Set 14 | dover
# Processing Record 12 of Set 14 | dubna
# Processing Record 13 of Set 14 | severo-yeniseyskiy
# Processing Record 14 of Set 14 | awjilah
# Processing Record 15 of Set 14 | pueblo nuevo
# Processing Record 16 of Set 14 | popondetta
# Processing Record 17 of Set 14 | chenghai
# Processing Record 18 of Set 14 | laem sing
# Processing Record 19 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 20 of Set 14 | kyra
# Processing Record 21 of Set 14 | kijang
# Processing Record 22 of Set 14 | piranshahr
# Processing Record 23 of Set 14 | kabalo
# Processing Record 24 of Set 14 | mangaratiba
# Processing Record 25 of Set 14 | zheleznodorozhnyy
# Processing Record 26 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 27 of Set 14 | bury saint edmunds
# City not found. Skipping...
# Processing Record 28 of Set 14 | akcaabat
# Processing Record 29 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 30 of Set 14 | taraz
# Processing Record 31 of Set 14 | san pedro
# Processing Record 32 of Set 14 | olinda
# Processing Record 33 of Set 14 | kohlu
# Processing Record 34 of Set 14 | hualmay
# Processing Record 35 of Set 14 | acajutla
# Processing Record 36 of Set 14 | hervey bay
# Processing Record 37 of Set 14 | tyumentsevo
# Processing Record 38 of Set 14 | hambantota
# Processing Record 39 of Set 14 | kerteh
# City not found. Skipping...
# Processing Record 40 of Set 14 | roebourne
# Processing Record 41 of Set 14 | xichang
# Processing Record 42 of Set 14 | alcaniz
# Processing Record 43 of Set 14 | zhezkazgan
# Processing Record 44 of Set 14 | doha
# Processing Record 45 of Set 14 | senador guiomard
# Processing Record 46 of Set 14 | kasane
# Processing Record 47 of Set 14 | general jose eduvigis diaz
# Processing Record 48 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 14 | naze
# Processing Record 50 of Set 14 | loiza
# Processing Record 1 of Set 15 | obidos
# Processing Record 2 of Set 15 | suao
# City not found. Skipping...
# Processing Record 3 of Set 15 | ossora
# Processing Record 4 of Set 15 | paungde
# Processing Record 5 of Set 15 | kingman
# Processing Record 6 of Set 15 | sakaraha
# Processing Record 7 of Set 15 | khanpur
# Processing Record 8 of Set 15 | sungaipenuh
# Processing Record 9 of Set 15 | loano
# Processing Record 10 of Set 15 | jedovnice
# Processing Record 11 of Set 15 | novo cruzeiro
# Processing Record 12 of Set 15 | husavik
# Processing Record 13 of Set 15 | praia da vitoria
# Processing Record 14 of Set 15 | eyl
# Processing Record 15 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 16 of Set 15 | tawnat
# City not found. Skipping...
# Processing Record 17 of Set 15 | homer
# Processing Record 18 of Set 15 | muros
# Processing Record 19 of Set 15 | pitimbu
# Processing Record 20 of Set 15 | moses lake
# Processing Record 21 of Set 15 | santa maria
# Processing Record 22 of Set 15 | huarmey
# Processing Record 23 of Set 15 | kobojango
# City not found. Skipping...
# Processing Record 24 of Set 15 | kudahuvadhoo
# Processing Record 25 of Set 15 | congonhas
# Processing Record 26 of Set 15 | dengfeng
# Processing Record 27 of Set 15 | sivas
# Processing Record 28 of Set 15 | purpe
# Processing Record 29 of Set 15 | lima
# Processing Record 30 of Set 15 | lewistown
# Processing Record 31 of Set 15 | awassa
# Processing Record 32 of Set 15 | bud
# Processing Record 33 of Set 15 | terrace
# Processing Record 34 of Set 15 | deputatskiy
# Processing Record 35 of Set 15 | namtsy
# Processing Record 36 of Set 15 | saint-augustin
# Processing Record 37 of Set 15 | waingapu
# Processing Record 38 of Set 15 | sidney
# Processing Record 39 of Set 15 | esmeraldas
# Processing Record 40 of Set 15 | imbituba
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 684

# %%
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Nouakchott  18.0858  -15.9785     73.33        41         100
# 1      Araouane  18.9048   -3.5265     70.18        16          98
# 2        Avarua -21.2078 -159.7750     78.85        83          40
# 3  Punta Arenas -53.1500  -70.9167     53.71        58          75
# 4   Pangnirtung  66.1451  -65.7125     19.40        86          75
# 5         Pisco -13.7000  -76.2167     73.45        68           0
# 6    Kaitangata -46.2817  169.8464     61.03        84         100
# 7        Yulara -25.2406  130.9889     71.44        46          57
# 8      Bilibino  68.0546  166.4372    -40.52        99          65
# 9       Fortuna  40.5982 -124.1573     51.66        97          90
#
#    Wind Speed Country                 Date
# 0        9.62      MR  2021-12-04 20:29:30
# 1       11.88      ML  2021-12-04 20:33:47
# 2        4.61      CK  2021-12-04 20:33:24
# 3       26.46      CL  2021-12-04 20:33:41
# 4        5.75      CA  2021-12-04 20:33:47
# 5       18.41      PE  2021-12-04 20:33:48
# 6        8.52      NZ  2021-12-04 20:33:48
# 7       16.11      AU  2021-12-04 20:33:48
# 8        4.76      RU  2021-12-04 20:33:48
# 9        0.00      US  2021-12-04 20:31:13

# %%
New_Column_Order = ["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed"]

# %%
city_data_final_df = city_data_df[New_Column_Order]

# %%
city_data_final_df.head(3)
# Out:
#          City Country                 Date      Lat       Lng  Max Temp  \
# 0  Nouakchott      MR  2021-12-04 20:29:30  18.0858  -15.9785     73.33
# 1    Araouane      ML  2021-12-04 20:33:47  18.9048   -3.5265     70.18
# 2      Avarua      CK  2021-12-04 20:33:24 -21.2078 -159.7750     78.85
#
#    Humidity  Cloudiness  Wind Speed
# 0        41         100        9.62
# 1        16          98       11.88
# 2        83          40        4.61

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
