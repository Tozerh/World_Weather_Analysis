# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy  
from config import weather_api_key
import time
from datetime import datetime
import requests

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="
key = weather_api_key
request_url = f"{url}{key}"

# %%
#gathers coordinates and creates list named 'cities'
coordinates = list(lat_lngs)
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)

# %%
len(cities)
# Out:
# 764

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = request_url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ") 
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | port elizabeth
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | dudinka
# Processing Record 4 of Set 1 | kodiak
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | ilulissat
# Processing Record 7 of Set 1 | ulagan
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | dikson
# Processing Record 10 of Set 1 | pala
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | saint-philippe
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | georgetown
# Processing Record 15 of Set 1 | kapaa
# Processing Record 16 of Set 1 | butaritari
# Processing Record 17 of Set 1 | sao felix do xingu
# Processing Record 18 of Set 1 | phan thiet
# Processing Record 19 of Set 1 | mocajuba
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | mahebourg
# Processing Record 22 of Set 1 | zeya
# Processing Record 23 of Set 1 | klaksvik
# Processing Record 24 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 1 | sabha
# Processing Record 26 of Set 1 | kefalos
# Processing Record 27 of Set 1 | barbar
# City not found. Skipping...
# Processing Record 28 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 1 | aldan
# Processing Record 30 of Set 1 | redlands
# Processing Record 31 of Set 1 | ust-omchug
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 1 | parabel
# Processing Record 35 of Set 1 | faanui
# Processing Record 36 of Set 1 | lorengau
# Processing Record 37 of Set 1 | atuona
# Processing Record 38 of Set 1 | wajir
# Processing Record 39 of Set 1 | dongsheng
# Processing Record 40 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 1 | micheweni
# Processing Record 42 of Set 1 | akonolinga
# Processing Record 43 of Set 1 | saskylakh
# Processing Record 44 of Set 1 | lavrentiya
# Processing Record 45 of Set 1 | udachnyy
# Processing Record 46 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 47 of Set 1 | dodge city
# Processing Record 48 of Set 1 | zalha
# Processing Record 49 of Set 1 | arraial do cabo
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | srednekolymsk
# Processing Record 2 of Set 2 | kenora
# Processing Record 3 of Set 2 | egvekinot
# Processing Record 4 of Set 2 | chokurdakh
# Processing Record 5 of Set 2 | hualmay
# Processing Record 6 of Set 2 | tucumcari
# Processing Record 7 of Set 2 | saldanha
# Processing Record 8 of Set 2 | lewisporte
# Processing Record 9 of Set 2 | alice springs
# Processing Record 10 of Set 2 | banes
# Processing Record 11 of Set 2 | sitka
# Processing Record 12 of Set 2 | awjilah
# Processing Record 13 of Set 2 | dalton
# Processing Record 14 of Set 2 | hambantota
# Processing Record 15 of Set 2 | port lincoln
# Processing Record 16 of Set 2 | yulara
# Processing Record 17 of Set 2 | jamestown
# Processing Record 18 of Set 2 | yellowknife
# Processing Record 19 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 2 | porto santo
# Processing Record 21 of Set 2 | bilibino
# Processing Record 22 of Set 2 | puerto ayora
# Processing Record 23 of Set 2 | bredasdorp
# Processing Record 24 of Set 2 | port alfred
# Processing Record 25 of Set 2 | sapa
# Processing Record 26 of Set 2 | longyearbyen
# Processing Record 27 of Set 2 | new norfolk
# Processing Record 28 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 2 | libertador general san martin
# Processing Record 30 of Set 2 | faya
# Processing Record 31 of Set 2 | kirkcudbright
# Processing Record 32 of Set 2 | hasaki
# Processing Record 33 of Set 2 | vila franca do campo
# Processing Record 34 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 35 of Set 2 | barrow
# Processing Record 36 of Set 2 | wisconsin rapids
# Processing Record 37 of Set 2 | bluff
# Processing Record 38 of Set 2 | san juan
# Processing Record 39 of Set 2 | punta arenas
# Processing Record 40 of Set 2 | piacabucu
# Processing Record 41 of Set 2 | aykhal
# Processing Record 42 of Set 2 | maua
# Processing Record 43 of Set 2 | ponta do sol
# Processing Record 44 of Set 2 | tuktoyaktuk
# Processing Record 45 of Set 2 | tigil
# Processing Record 46 of Set 2 | korla
# Processing Record 47 of Set 2 | khatanga
# Processing Record 48 of Set 2 | luderitz
# Processing Record 49 of Set 2 | senneterre
# Processing Record 50 of Set 2 | pevek
# Processing Record 1 of Set 3 | kirovsk
# Processing Record 2 of Set 3 | talaya
# Processing Record 3 of Set 3 | vila velha
# Processing Record 4 of Set 3 | la asuncion
# Processing Record 5 of Set 3 | san jeronimo
# Processing Record 6 of Set 3 | upernavik
# Processing Record 7 of Set 3 | male
# Processing Record 8 of Set 3 | villa de cura
# Processing Record 9 of Set 3 | ust-maya
# Processing Record 10 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 3 | olafsvik
# Processing Record 12 of Set 3 | canon city
# Processing Record 13 of Set 3 | burns lake
# Processing Record 14 of Set 3 | nikolskoye
# Processing Record 15 of Set 3 | fairbanks
# Processing Record 16 of Set 3 | pitimbu
# Processing Record 17 of Set 3 | maghama
# City not found. Skipping...
# Processing Record 18 of Set 3 | sonamukhi
# Processing Record 19 of Set 3 | fevralsk
# City not found. Skipping...
# Processing Record 20 of Set 3 | vagur
# Processing Record 21 of Set 3 | payson
# Processing Record 22 of Set 3 | antofagasta
# Processing Record 23 of Set 3 | ancud
# Processing Record 24 of Set 3 | victoria
# Processing Record 25 of Set 3 | eyl
# Processing Record 26 of Set 3 | cabaiguan
# Processing Record 27 of Set 3 | celestun
# Processing Record 28 of Set 3 | cherskiy
# Processing Record 29 of Set 3 | vygonichi
# Processing Record 30 of Set 3 | hilo
# Processing Record 31 of Set 3 | amazar
# Processing Record 32 of Set 3 | bachaquero
# Processing Record 33 of Set 3 | mount pleasant
# Processing Record 34 of Set 3 | mataura
# Processing Record 35 of Set 3 | port macquarie
# Processing Record 36 of Set 3 | anadyr
# Processing Record 37 of Set 3 | traverse city
# Processing Record 38 of Set 3 | mount gambier
# Processing Record 39 of Set 3 | poum
# Processing Record 40 of Set 3 | dunedin
# Processing Record 41 of Set 3 | vardo
# Processing Record 42 of Set 3 | san cristobal
# Processing Record 43 of Set 3 | sao filipe
# Processing Record 44 of Set 3 | vanimo
# Processing Record 45 of Set 3 | mehamn
# Processing Record 46 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 3 | eldorado
# Processing Record 48 of Set 3 | luena
# Processing Record 49 of Set 3 | pisco
# Processing Record 50 of Set 3 | une
# Processing Record 1 of Set 4 | esperance
# Processing Record 2 of Set 4 | yar-sale
# Processing Record 3 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 4 | roswell
# Processing Record 5 of Set 4 | port hedland
# Processing Record 6 of Set 4 | cabo san lucas
# Processing Record 7 of Set 4 | torbay
# Processing Record 8 of Set 4 | gushikawa
# Processing Record 9 of Set 4 | paamiut
# Processing Record 10 of Set 4 | constitucion
# Processing Record 11 of Set 4 | maroantsetra
# Processing Record 12 of Set 4 | nazca
# Processing Record 13 of Set 4 | alyangula
# Processing Record 14 of Set 4 | tutoia
# Processing Record 15 of Set 4 | usinsk
# Processing Record 16 of Set 4 | port hardy
# Processing Record 17 of Set 4 | victor harbor
# Processing Record 18 of Set 4 | east london
# Processing Record 19 of Set 4 | morgan city
# Processing Record 20 of Set 4 | severo-kurilsk
# Processing Record 21 of Set 4 | muli
# Processing Record 22 of Set 4 | brewster
# Processing Record 23 of Set 4 | hobyo
# Processing Record 24 of Set 4 | kuala terengganu
# Processing Record 25 of Set 4 | gibsons
# Processing Record 26 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 4 | lasa
# Processing Record 28 of Set 4 | ust-kut
# Processing Record 29 of Set 4 | chornobay
# Processing Record 30 of Set 4 | pasni
# Processing Record 31 of Set 4 | lebu
# Processing Record 32 of Set 4 | botou
# Processing Record 33 of Set 4 | sobolevo
# Processing Record 34 of Set 4 | havre-saint-pierre
# Processing Record 35 of Set 4 | charters towers
# Processing Record 36 of Set 4 | killybegs
# Processing Record 37 of Set 4 | leningradskiy
# Processing Record 38 of Set 4 | college
# Processing Record 39 of Set 4 | taltal
# Processing Record 40 of Set 4 | dwarka
# Processing Record 41 of Set 4 | mitu
# Processing Record 42 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 4 | juan de acosta
# Processing Record 44 of Set 4 | shimoda
# Processing Record 45 of Set 4 | tabou
# Processing Record 46 of Set 4 | beringovskiy
# Processing Record 47 of Set 4 | seddon
# Processing Record 48 of Set 4 | mandurah
# Processing Record 49 of Set 4 | bayan
# Processing Record 50 of Set 4 | mbour
# Processing Record 1 of Set 5 | los llanos de aridane
# Processing Record 2 of Set 5 | oranjestad
# Processing Record 3 of Set 5 | brownwood
# Processing Record 4 of Set 5 | beauchamps
# Processing Record 5 of Set 5 | riacho de santana
# Processing Record 6 of Set 5 | muisne
# Processing Record 7 of Set 5 | stornoway
# Processing Record 8 of Set 5 | waipawa
# Processing Record 9 of Set 5 | qaqortoq
# Processing Record 10 of Set 5 | iqaluit
# Processing Record 11 of Set 5 | nagato
# Processing Record 12 of Set 5 | hamilton
# Processing Record 13 of Set 5 | tiksi
# Processing Record 14 of Set 5 | altoona
# Processing Record 15 of Set 5 | comodoro rivadavia
# Processing Record 16 of Set 5 | bethel
# Processing Record 17 of Set 5 | dingzhou
# Processing Record 18 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 19 of Set 5 | carnarvon
# Processing Record 20 of Set 5 | palmer
# Processing Record 21 of Set 5 | norman wells
# Processing Record 22 of Set 5 | bambous virieux
# Processing Record 23 of Set 5 | milingimbi
# City not found. Skipping...
# Processing Record 24 of Set 5 | codrington
# Processing Record 25 of Set 5 | sao joao da barra
# Processing Record 26 of Set 5 | mardin
# Processing Record 27 of Set 5 | zandvoort
# Processing Record 28 of Set 5 | qaanaaq
# Processing Record 29 of Set 5 | tazovskiy
# Processing Record 30 of Set 5 | berlevag
# Processing Record 31 of Set 5 | thompson
# Processing Record 32 of Set 5 | mar del plata
# Processing Record 33 of Set 5 | tadine
# Processing Record 34 of Set 5 | magadi
# Processing Record 35 of Set 5 | jumla
# Processing Record 36 of Set 5 | scalea
# Processing Record 37 of Set 5 | hermanus
# Processing Record 38 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 5 | kloulklubed
# Processing Record 40 of Set 5 | visnes
# Processing Record 41 of Set 5 | ostrovnoy
# Processing Record 42 of Set 5 | dengzhou
# Processing Record 43 of Set 5 | livani
# Processing Record 44 of Set 5 | dianopolis
# City not found. Skipping...
# Processing Record 45 of Set 5 | sinnamary
# Processing Record 46 of Set 5 | geraldton
# Processing Record 47 of Set 5 | aberdeen
# Processing Record 48 of Set 5 | maltahohe
# Processing Record 49 of Set 5 | pak phanang
# Processing Record 50 of Set 5 | audru
# Processing Record 1 of Set 6 | cerrito
# Processing Record 2 of Set 6 | luang prabang
# Processing Record 3 of Set 6 | lagoa
# Processing Record 4 of Set 6 | kualakapuas
# Processing Record 5 of Set 6 | nakhon si thammarat
# Processing Record 6 of Set 6 | machiques
# Processing Record 7 of Set 6 | guajara-mirim
# City not found. Skipping...
# Processing Record 8 of Set 6 | pangnirtung
# Processing Record 9 of Set 6 | dalvik
# Processing Record 10 of Set 6 | jijiga
# Processing Record 11 of Set 6 | bredy
# Processing Record 12 of Set 6 | jijiang
# Processing Record 13 of Set 6 | sabang
# Processing Record 14 of Set 6 | san patricio
# Processing Record 15 of Set 6 | tuatapere
# Processing Record 16 of Set 6 | moville
# Processing Record 17 of Set 6 | carsamba
# Processing Record 18 of Set 6 | guasdualito
# Processing Record 19 of Set 6 | veraval
# Processing Record 20 of Set 6 | soyo
# Processing Record 21 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 22 of Set 6 | mchinji
# Processing Record 23 of Set 6 | ubinskoye
# Processing Record 24 of Set 6 | ribeira grande
# Processing Record 25 of Set 6 | nanortalik
# Processing Record 26 of Set 6 | okitipupa
# Processing Record 27 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 28 of Set 6 | kruisfontein
# Processing Record 29 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 6 | chor
# Processing Record 31 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 6 | narsaq
# Processing Record 33 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 6 | clyde river
# Processing Record 35 of Set 6 | hayden
# Processing Record 36 of Set 6 | cidreira
# Processing Record 37 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 6 | bahir dar
# Processing Record 39 of Set 6 | copiapo
# Processing Record 40 of Set 6 | dori
# Processing Record 41 of Set 6 | nhulunbuy
# Processing Record 42 of Set 6 | tubmanburg
# Processing Record 43 of Set 6 | avarua
# Processing Record 44 of Set 6 | mixtequilla
# City not found. Skipping...
# Processing Record 45 of Set 6 | bambui
# Processing Record 46 of Set 6 | gornopravdinsk
# Processing Record 47 of Set 6 | svetlogorsk
# Processing Record 48 of Set 6 | salalah
# Processing Record 49 of Set 6 | shangzhi
# Processing Record 50 of Set 6 | prado
# Processing Record 1 of Set 7 | skibbereen
# Processing Record 2 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 3 of Set 7 | tasiilaq
# Processing Record 4 of Set 7 | bengkulu
# Processing Record 5 of Set 7 | santana
# Processing Record 6 of Set 7 | sao raimundo nonato
# Processing Record 7 of Set 7 | provideniya
# Processing Record 8 of Set 7 | ola
# Processing Record 9 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 10 of Set 7 | eyemouth
# Processing Record 11 of Set 7 | saint-augustin
# Processing Record 12 of Set 7 | amga
# Processing Record 13 of Set 7 | jesup
# Processing Record 14 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 15 of Set 7 | mayumba
# Processing Record 16 of Set 7 | kamenka
# Processing Record 17 of Set 7 | maceio
# Processing Record 18 of Set 7 | milkovo
# Processing Record 19 of Set 7 | cap malheureux
# Processing Record 20 of Set 7 | ararat
# Processing Record 21 of Set 7 | talawdi
# City not found. Skipping...
# Processing Record 22 of Set 7 | bin qirdan
# Processing Record 23 of Set 7 | praia da vitoria
# Processing Record 24 of Set 7 | kaitangata
# Processing Record 25 of Set 7 | airai
# Processing Record 26 of Set 7 | sanmenxia
# Processing Record 27 of Set 7 | taunggyi
# Processing Record 28 of Set 7 | acapulco
# Processing Record 29 of Set 7 | cazaje
# City not found. Skipping...
# Processing Record 30 of Set 7 | hofn
# Processing Record 31 of Set 7 | ulladulla
# Processing Record 32 of Set 7 | pangody
# Processing Record 33 of Set 7 | san felipe
# Processing Record 34 of Set 7 | rio gallegos
# Processing Record 35 of Set 7 | guerrero negro
# Processing Record 36 of Set 7 | chato
# Processing Record 37 of Set 7 | ossora
# Processing Record 38 of Set 7 | bundaberg
# Processing Record 39 of Set 7 | kavieng
# Processing Record 40 of Set 7 | saint george
# Processing Record 41 of Set 7 | coro
# Processing Record 42 of Set 7 | caravelas
# Processing Record 43 of Set 7 | urk
# Processing Record 44 of Set 7 | baiyin
# Processing Record 45 of Set 7 | alekseyevka
# Processing Record 46 of Set 7 | taga
# Processing Record 47 of Set 7 | bokoro
# Processing Record 48 of Set 7 | dingle
# Processing Record 49 of Set 7 | komsomolskiy
# Processing Record 50 of Set 7 | staryy nadym
# Processing Record 1 of Set 8 | dos hermanas
# Processing Record 2 of Set 8 | coihaique
# Processing Record 3 of Set 8 | palana
# Processing Record 4 of Set 8 | galich
# Processing Record 5 of Set 8 | rosetta
# Processing Record 6 of Set 8 | honningsvag
# Processing Record 7 of Set 8 | kargasok
# Processing Record 8 of Set 8 | verkhovazhye
# Processing Record 9 of Set 8 | beira
# Processing Record 10 of Set 8 | kuryk
# Processing Record 11 of Set 8 | jalu
# Processing Record 12 of Set 8 | rantauprapat
# Processing Record 13 of Set 8 | lomza
# Processing Record 14 of Set 8 | inhambane
# Processing Record 15 of Set 8 | makakilo city
# Processing Record 16 of Set 8 | mora
# Processing Record 17 of Set 8 | mao
# Processing Record 18 of Set 8 | jieshi
# Processing Record 19 of Set 8 | alegrete
# Processing Record 20 of Set 8 | aswan
# Processing Record 21 of Set 8 | opuwo
# Processing Record 22 of Set 8 | plettenberg bay
# Processing Record 23 of Set 8 | soe
# Processing Record 24 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 8 | kopavogur
# Processing Record 26 of Set 8 | pacific grove
# Processing Record 27 of Set 8 | cockburn town
# Processing Record 28 of Set 8 | belmonte
# Processing Record 29 of Set 8 | asfi
# Processing Record 30 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 31 of Set 8 | tolaga bay
# Processing Record 32 of Set 8 | castro
# Processing Record 33 of Set 8 | meulaboh
# Processing Record 34 of Set 8 | talnakh
# Processing Record 35 of Set 8 | altay
# Processing Record 36 of Set 8 | ondangwa
# Processing Record 37 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 38 of Set 8 | batticaloa
# Processing Record 39 of Set 8 | ahipara
# Processing Record 40 of Set 8 | eureka
# Processing Record 41 of Set 8 | vrangel
# Processing Record 42 of Set 8 | fort nelson
# Processing Record 43 of Set 8 | vineland
# Processing Record 44 of Set 8 | kerema
# Processing Record 45 of Set 8 | strezhevoy
# Processing Record 46 of Set 8 | aasiaat
# Processing Record 47 of Set 8 | bocaranga
# City not found. Skipping...
# Processing Record 48 of Set 8 | pokhara
# Processing Record 49 of Set 8 | gat
# Processing Record 50 of Set 8 | krasnyy chikoy
# Processing Record 1 of Set 9 | matagami
# Processing Record 2 of Set 9 | bambanglipuro
# Processing Record 3 of Set 9 | margherita
# Processing Record 4 of Set 9 | tezu
# Processing Record 5 of Set 9 | christchurch
# Processing Record 6 of Set 9 | yinchuan
# Processing Record 7 of Set 9 | leninsk
# Processing Record 8 of Set 9 | kirakira
# Processing Record 9 of Set 9 | sorong
# Processing Record 10 of Set 9 | vao
# Processing Record 11 of Set 9 | goderich
# Processing Record 12 of Set 9 | souillac
# Processing Record 13 of Set 9 | semily
# Processing Record 14 of Set 9 | touros
# Processing Record 15 of Set 9 | baft
# Processing Record 16 of Set 9 | kidal
# Processing Record 17 of Set 9 | madimba
# Processing Record 18 of Set 9 | turinskaya sloboda
# Processing Record 19 of Set 9 | zhigansk
# Processing Record 20 of Set 9 | akdepe
# Processing Record 21 of Set 9 | sola
# Processing Record 22 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 23 of Set 9 | arenapolis
# Processing Record 24 of Set 9 | barreirinhas
# Processing Record 25 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 9 | tessalit
# Processing Record 27 of Set 9 | vallenar
# Processing Record 28 of Set 9 | biak
# Processing Record 29 of Set 9 | sangmelima
# Processing Record 30 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 31 of Set 9 | te anau
# Processing Record 32 of Set 9 | casablanca
# Processing Record 33 of Set 9 | jacareacanga
# Processing Record 34 of Set 9 | venado tuerto
# Processing Record 35 of Set 9 | princeton
# Processing Record 36 of Set 9 | coquimbo
# Processing Record 37 of Set 9 | oktyabrskiy
# Processing Record 38 of Set 9 | sinazongwe
# Processing Record 39 of Set 9 | adrar
# Processing Record 40 of Set 9 | buchanan
# Processing Record 41 of Set 9 | hithadhoo
# Processing Record 42 of Set 9 | samarai
# Processing Record 43 of Set 9 | kavaratti
# Processing Record 44 of Set 9 | christiana
# Processing Record 45 of Set 9 | jimenez
# Processing Record 46 of Set 9 | warrington
# Processing Record 47 of Set 9 | ranong
# Processing Record 48 of Set 9 | nome
# Processing Record 49 of Set 9 | champerico
# Processing Record 50 of Set 9 | port blair
# Processing Record 1 of Set 10 | maridi
# Processing Record 2 of Set 10 | gannan
# Processing Record 3 of Set 10 | tabas
# Processing Record 4 of Set 10 | gobabis
# Processing Record 5 of Set 10 | itarema
# Processing Record 6 of Set 10 | portland
# Processing Record 7 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 8 of Set 10 | naze
# Processing Record 9 of Set 10 | ilhabela
# Processing Record 10 of Set 10 | leona vicario
# Processing Record 11 of Set 10 | pontevedra
# Processing Record 12 of Set 10 | tuy hoa
# Processing Record 13 of Set 10 | bako
# Processing Record 14 of Set 10 | bereda
# Processing Record 15 of Set 10 | vila
# Processing Record 16 of Set 10 | sorland
# Processing Record 17 of Set 10 | havoysund
# Processing Record 18 of Set 10 | chara
# Processing Record 19 of Set 10 | bathsheba
# Processing Record 20 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 21 of Set 10 | bell ville
# Processing Record 22 of Set 10 | bilma
# Processing Record 23 of Set 10 | rocha
# Processing Record 24 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 25 of Set 10 | warwick
# Processing Record 26 of Set 10 | muros
# Processing Record 27 of Set 10 | killeen
# Processing Record 28 of Set 10 | japura
# Processing Record 29 of Set 10 | gurgan
# City not found. Skipping...
# Processing Record 30 of Set 10 | kaohsiung
# Processing Record 31 of Set 10 | deputatskiy
# Processing Record 32 of Set 10 | kathmandu
# Processing Record 33 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 10 | miri
# Processing Record 35 of Set 10 | iranshahr
# Processing Record 36 of Set 10 | grand-santi
# Processing Record 37 of Set 10 | songjianghe
# Processing Record 38 of Set 10 | kushiro
# Processing Record 39 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 10 | grand gaube
# Processing Record 41 of Set 10 | andros town
# Processing Record 42 of Set 10 | dabakala
# Processing Record 43 of Set 10 | ponta delgada
# Processing Record 44 of Set 10 | north bend
# Processing Record 45 of Set 10 | wasilla
# Processing Record 46 of Set 10 | chuy
# Processing Record 47 of Set 10 | corsicana
# Processing Record 48 of Set 10 | mantua
# Processing Record 49 of Set 10 | port-gentil
# Processing Record 50 of Set 10 | maragogi
# Processing Record 1 of Set 11 | caborca
# Processing Record 2 of Set 11 | tazmalt
# Processing Record 3 of Set 11 | tari
# Processing Record 4 of Set 11 | quesnel
# Processing Record 5 of Set 11 | tura
# Processing Record 6 of Set 11 | ozark
# Processing Record 7 of Set 11 | nasice
# Processing Record 8 of Set 11 | sabzevar
# Processing Record 9 of Set 11 | kokhma
# Processing Record 10 of Set 11 | eldikan
# City not found. Skipping...
# Processing Record 11 of Set 11 | tambura
# Processing Record 12 of Set 11 | belaya gora
# Processing Record 13 of Set 11 | sistranda
# Processing Record 14 of Set 11 | nawa
# Processing Record 15 of Set 11 | pedra branca
# Processing Record 16 of Set 11 | hirara
# Processing Record 17 of Set 11 | rincon
# Processing Record 18 of Set 11 | kibuye
# Processing Record 19 of Set 11 | lata
# Processing Record 20 of Set 11 | elat
# Processing Record 21 of Set 11 | yuzhno-kurilsk
# Processing Record 22 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 23 of Set 11 | monte azul
# Processing Record 24 of Set 11 | zwedru
# Processing Record 25 of Set 11 | loviisa
# Processing Record 26 of Set 11 | nampula
# Processing Record 27 of Set 11 | santa isabel do rio negro
# Processing Record 28 of Set 11 | okhotsk
# Processing Record 29 of Set 11 | te horo
# Processing Record 30 of Set 11 | srandakan
# Processing Record 31 of Set 11 | rapina
# Processing Record 32 of Set 11 | turukhansk
# Processing Record 33 of Set 11 | malanje
# Processing Record 34 of Set 11 | anupgarh
# Processing Record 35 of Set 11 | krasnoselkup
# Processing Record 36 of Set 11 | goulburn
# Processing Record 37 of Set 11 | waingapu
# Processing Record 38 of Set 11 | praya
# Processing Record 39 of Set 11 | porto nacional
# Processing Record 40 of Set 11 | bhanpuri
# Processing Record 41 of Set 11 | oriximina
# Processing Record 42 of Set 11 | atar
# Processing Record 43 of Set 11 | gigmoto
# Processing Record 44 of Set 11 | maniitsoq
# Processing Record 45 of Set 11 | namatanai
# Processing Record 46 of Set 11 | san fernando
# Processing Record 47 of Set 11 | madison
# Processing Record 48 of Set 11 | alofi
# Processing Record 49 of Set 11 | gidam
# Processing Record 50 of Set 11 | volkhov
# Processing Record 1 of Set 12 | port hawkesbury
# Processing Record 2 of Set 12 | upata
# Processing Record 3 of Set 12 | mana
# Processing Record 4 of Set 12 | helong
# Processing Record 5 of Set 12 | xining
# Processing Record 6 of Set 12 | bouloupari
# Processing Record 7 of Set 12 | lobito
# Processing Record 8 of Set 12 | inirida
# Processing Record 9 of Set 12 | mackay
# Processing Record 10 of Set 12 | doha
# Processing Record 11 of Set 12 | tacoronte
# Processing Record 12 of Set 12 | lar gerd
# City not found. Skipping...
# Processing Record 13 of Set 12 | jamame
# Processing Record 14 of Set 12 | mweka
# Processing Record 15 of Set 12 | viljoenskroon
# Processing Record 16 of Set 12 | parkes
# Processing Record 17 of Set 12 | namibe
# Processing Record 18 of Set 12 | ciudad bolivar
# Processing Record 19 of Set 12 | tselinnoye
# Processing Record 20 of Set 12 | la ronge
# Processing Record 21 of Set 12 | cestas
# Processing Record 22 of Set 12 | talara
# Processing Record 23 of Set 12 | la paz
# Processing Record 24 of Set 12 | vestmannaeyjar
# Processing Record 25 of Set 12 | broome
# Processing Record 26 of Set 12 | gambela
# Processing Record 27 of Set 12 | moussoro
# Processing Record 28 of Set 12 | changuinola
# Processing Record 29 of Set 12 | aksu
# Processing Record 30 of Set 12 | saint-pierre
# Processing Record 31 of Set 12 | pocos de caldas
# Processing Record 32 of Set 12 | san vicente
# Processing Record 33 of Set 12 | belomorsk
# Processing Record 34 of Set 12 | gamba
# Processing Record 35 of Set 12 | paramonga
# Processing Record 36 of Set 12 | luganville
# Processing Record 37 of Set 12 | pemba
# Processing Record 38 of Set 12 | encheng
# Processing Record 39 of Set 12 | kieta
# Processing Record 40 of Set 12 | bonavista
# Processing Record 41 of Set 12 | san miguel de cauri
# Processing Record 42 of Set 12 | brokopondo
# Processing Record 43 of Set 12 | mnogovershinnyy
# Processing Record 44 of Set 12 | ngunguru
# Processing Record 45 of Set 12 | balkhash
# Processing Record 46 of Set 12 | sampit
# Processing Record 47 of Set 12 | vostok
# Processing Record 48 of Set 12 | sesvete
# Processing Record 49 of Set 12 | cururupu
# Processing Record 50 of Set 12 | yaan
# Processing Record 1 of Set 13 | troitsko-pechorsk
# Processing Record 2 of Set 13 | sayat
# Processing Record 3 of Set 13 | puri
# Processing Record 4 of Set 13 | tenosique
# Processing Record 5 of Set 13 | humaita
# Processing Record 6 of Set 13 | taoudenni
# Processing Record 7 of Set 13 | ewa beach
# Processing Record 8 of Set 13 | saint-joseph
# Processing Record 9 of Set 13 | irsha
# Processing Record 10 of Set 13 | dzhebariki-khaya
# Processing Record 11 of Set 13 | sirfa
# City not found. Skipping...
# Processing Record 12 of Set 13 | nara
# Processing Record 13 of Set 13 | alta floresta
# Processing Record 14 of Set 13 | mokrousovo
# Processing Record 15 of Set 13 | haines junction
# Processing Record 16 of Set 13 | baykit
# Processing Record 17 of Set 13 | tahe
# Processing Record 18 of Set 13 | beloha
# Processing Record 19 of Set 13 | omboue
# Processing Record 20 of Set 13 | teya
# Processing Record 21 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 22 of Set 13 | abbeville
# Processing Record 23 of Set 13 | kincardine
# Processing Record 24 of Set 13 | flin flon
# Processing Record 25 of Set 13 | saint anthony
# Processing Record 26 of Set 13 | ambunti
# Processing Record 27 of Set 13 | tabriz
# Processing Record 28 of Set 13 | vaitape
# Processing Record 29 of Set 13 | brigantine
# Processing Record 30 of Set 13 | buraydah
# Processing Record 31 of Set 13 | kano
# Processing Record 32 of Set 13 | moose factory
# Processing Record 33 of Set 13 | thunder bay
# Processing Record 34 of Set 13 | livramento
# Processing Record 35 of Set 13 | yomitan
# City not found. Skipping...
# Processing Record 36 of Set 13 | lethem
# Processing Record 37 of Set 13 | vilyuysk
# Processing Record 38 of Set 13 | mbandaka
# Processing Record 39 of Set 13 | sao goncalo do sapucai
# Processing Record 40 of Set 13 | arawa
# Processing Record 41 of Set 13 | salekhard
# Processing Record 42 of Set 13 | stantsionno-oyashinskiy
# Processing Record 43 of Set 13 | uzhur
# Processing Record 44 of Set 13 | kutum
# Processing Record 45 of Set 13 | tilichiki
# Processing Record 46 of Set 13 | dolinsk
# Processing Record 47 of Set 13 | alcaniz
# Processing Record 48 of Set 13 | kamuli
# Processing Record 49 of Set 13 | kindu
# Processing Record 50 of Set 13 | hinton
# Processing Record 1 of Set 14 | lodwar
# Processing Record 2 of Set 14 | almeirim
# Processing Record 3 of Set 14 | fulda
# Processing Record 4 of Set 14 | orapa
# Processing Record 5 of Set 14 | makat
# Processing Record 6 of Set 14 | sherbrooke
# Processing Record 7 of Set 14 | boden
# Processing Record 8 of Set 14 | rawson
# Processing Record 9 of Set 14 | winston
# Processing Record 10 of Set 14 | sept-iles
# Processing Record 11 of Set 14 | jardim
# Processing Record 12 of Set 14 | ishim
# Processing Record 13 of Set 14 | pennsauken
# Processing Record 14 of Set 14 | king city
# Processing Record 15 of Set 14 | gavle
# Processing Record 16 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 17 of Set 14 | dryden
# Processing Record 18 of Set 14 | emerald
# Processing Record 19 of Set 14 | qasigiannguit
# Processing Record 20 of Set 14 | carutapera
# Processing Record 21 of Set 14 | walvis bay
# Processing Record 22 of Set 14 | natal
# Processing Record 23 of Set 14 | umea
# Processing Record 24 of Set 14 | gua musang
# Processing Record 25 of Set 14 | changji
# Processing Record 26 of Set 14 | ayrum
# Processing Record 27 of Set 14 | tyssedal
# Processing Record 28 of Set 14 | ouargaye
# Processing Record 29 of Set 14 | villanueva de la serena
# Processing Record 30 of Set 14 | olinda
# Processing Record 31 of Set 14 | port shepstone
# Processing Record 32 of Set 14 | santa rosa
# Processing Record 33 of Set 14 | linares
# Processing Record 34 of Set 14 | mawlaik
# Processing Record 35 of Set 14 | port augusta
# Processing Record 36 of Set 14 | hami
# Processing Record 37 of Set 14 | mizdah
# Processing Record 38 of Set 14 | kaka
# Processing Record 39 of Set 14 | millville
# Processing Record 40 of Set 14 | guamuchil
# Processing Record 41 of Set 14 | griffith
# Processing Record 42 of Set 14 | svetlaya
# Processing Record 43 of Set 14 | atbasar
# Processing Record 44 of Set 14 | van buren
# Processing Record 45 of Set 14 | mogilno
# Processing Record 46 of Set 14 | hovd
# Processing Record 47 of Set 14 | kungurtug
# Processing Record 48 of Set 14 | guane
# Processing Record 49 of Set 14 | glamoc
# Processing Record 50 of Set 14 | teteven
# Processing Record 1 of Set 15 | bonthe
# Processing Record 2 of Set 15 | avera
# Processing Record 3 of Set 15 | husavik
# Processing Record 4 of Set 15 | camacha
# Processing Record 5 of Set 15 | port pirie
# Processing Record 6 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 7 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 15 | tongliao
# Processing Record 9 of Set 15 | sabinas
# Processing Record 10 of Set 15 | umm kaddadah
# Processing Record 11 of Set 15 | yerbogachen
# Processing Record 12 of Set 15 | tiarei
# Processing Record 13 of Set 15 | biltine
# Processing Record 14 of Set 15 | kalas
# Processing Record 15 of Set 15 | sarkand
# Processing Record 16 of Set 15 | smyrna
# Processing Record 17 of Set 15 | gelemso
# Processing Record 18 of Set 15 | capitan meza
# Processing Record 19 of Set 15 | mountain home
# Processing Record 20 of Set 15 | ayorou
# Processing Record 21 of Set 15 | fortuna
# Processing Record 22 of Set 15 | nuuk
# Processing Record 23 of Set 15 | jabiru
# City not found. Skipping...
# Processing Record 24 of Set 15 | sidney
# Processing Record 25 of Set 15 | kiunga
# Processing Record 26 of Set 15 | la ligua
# Processing Record 27 of Set 15 | burstadt
# Processing Record 28 of Set 15 | palm valley
# Processing Record 29 of Set 15 | juneau
# Processing Record 30 of Set 15 | coalcoman
# City not found. Skipping...
# Processing Record 31 of Set 15 | katsuura
# Processing Record 32 of Set 15 | port hueneme
# Processing Record 33 of Set 15 | morondava
# Processing Record 34 of Set 15 | sisian
# Processing Record 35 of Set 15 | kasongo-lunda
# Processing Record 36 of Set 15 | bubaque
# Processing Record 37 of Set 15 | suntar
# Processing Record 38 of Set 15 | kropotkin
# Processing Record 39 of Set 15 | asau
# Processing Record 40 of Set 15 | kahului
# Processing Record 41 of Set 15 | cumberland
# Processing Record 42 of Set 15 | chiredzi
# Processing Record 43 of Set 15 | vestbygda
# City not found. Skipping...
# Processing Record 44 of Set 15 | kabarnet
# Processing Record 45 of Set 15 | kluang
# Processing Record 46 of Set 15 | margate
# Processing Record 47 of Set 15 | miles city
# Processing Record 48 of Set 15 | asayita
# City not found. Skipping...
# Processing Record 49 of Set 15 | huaihua
# Processing Record 50 of Set 15 | batagay-alyta
# Processing Record 1 of Set 16 | bejar
# Processing Record 2 of Set 16 | singleton
# Processing Record 3 of Set 16 | bandarbeyla
# Processing Record 4 of Set 16 | loreto
# Processing Record 5 of Set 16 | tabiauea
# City not found. Skipping...
# Processing Record 6 of Set 16 | jati
# Processing Record 7 of Set 16 | chimore
# Processing Record 8 of Set 16 | priargunsk
# Processing Record 9 of Set 16 | burica
# City not found. Skipping...
# Processing Record 10 of Set 16 | ojinaga
# Processing Record 11 of Set 16 | nantucket
# Processing Record 12 of Set 16 | dali
# Processing Record 13 of Set 16 | breaza
# Processing Record 14 of Set 16 | mayor pablo lagerenza
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 703

# %%
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port Elizabeth -33.9180   25.5701     63.10        94          90
# 1           Vaini -21.2000 -175.2000     84.36        74          40
# 2         Dudinka  69.4058   86.1778    -30.39       100          92
# 3          Kodiak  57.7900 -152.4072     26.11        68          90
# 4         Rikitea -23.1203 -134.9692     76.06        71          40
# 5       Ilulissat  69.2167  -51.1000     37.42        52          20
# 6          Ulagan  50.6321   87.9563      6.37        88          35
# 7          Albany  42.6001  -73.9662     41.81        73          85
# 8          Dikson  73.5069   80.5464    -22.86       100         100
# 9            Pala   9.3642   14.9046     78.04        28          88
#
#    Wind Speed Country                 Date Current Description
# 0       10.36      ZA  2021-12-04 22:29:52          light rain
# 1       12.66      TO  2021-12-04 22:28:14          light rain
# 2        5.57      RU  2021-12-04 22:35:05     overcast clouds
# 3        8.05      US  2021-12-04 22:28:28     overcast clouds
# 4       10.00      PF  2021-12-04 22:23:06    scattered clouds
# 5       31.07      GL  2021-12-04 22:27:09          few clouds
# 6        2.77      RU  2021-12-04 22:35:05    scattered clouds
# 7        7.05      US  2021-12-04 22:25:05     overcast clouds
# 8        9.75      RU  2021-12-04 22:27:02     overcast clouds
# 9        6.82      TD  2021-12-04 22:35:05     overcast clouds

# %%
New_Column_Order = ["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness",
                    "Wind Speed","Current Description"]

# %%
city_data_final_df = city_data_df[New_Column_Order]

# %%
city_data_final_df.head(3)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0  Port Elizabeth      ZA  2021-12-04 22:29:52 -33.9180   25.5701     63.10
# 1           Vaini      TO  2021-12-04 22:28:14 -21.2000 -175.2000     84.36
# 2         Dudinka      RU  2021-12-04 22:35:05  69.4058   86.1778    -30.39
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        94          90       10.36          light rain
# 1        74          40       12.66          light rain
# 2       100          92        5.57     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
